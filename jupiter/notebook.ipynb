# %%
s = "kishikishore is a worst boy"
t=s.split()
print(t)
# Out:
# ['kishikishore', 'is', 'a', 'worst', 'boy']

# %%
print()

# %%
list1=["kishore","is","a","worst","boy"]
s = "_".join(list1)
print(s)
# Out:
# kishore_is_a_worst_boy

# %%
s = "pankaj sharma sir"
words = s.split()                       # ['pankaj', 'sharma', 'sir']

# Get first letters using split and join only
initials = " ".join([w.split()[0][0] for w in words[:-1]])  # 'p s'
last_word = words[-1]                                       # 'sir'

result = " ".join([initials, last_word])
print(result)
#input : "pankaj sharma sir "
#output : "p s sir "
# Out:
# p s sir

# %%
s="th the kishikishore t is the worst"
i = s.find("the")
print(i)
# Out:
# 3

# %%
s="kishikishore is the worst"
t = s.replace("worst","best")
print(t)
# Out:
# kishikishore is the best

# %%
l=[1,2,3,4,5]
min11 = min(l)
max1 = max(l)
print("min:",min11)
print("max:",max1)
# Out:
# min: 1
# max: 5

# %%
del min
del max
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 del min
#       2 del max
#
# NameError: name 'min' is not defined

# %%
t = "This is a sample string for testing."
w = t.replace(" ", "")
sorted = sorted(w)
print(sorted)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[63], line 3
#       1 t = "This is a sample string for testing."
#       2 w = t.replace(" ", "")
# ----> 3 sorted = w.sort()
#       4 print(sorted)
#
# AttributeError: 'str' object has no attribute 'sort'

# %%
list1 = [5, 2, 9, 1, 5, 6]
sorted_list = sorted(list1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[64], line 2
#       1 list1 = [5, 2, 9, 1, 5, 6]
# ----> 2 sorted_list = sorted(list1)
#
# TypeError: 'list' object is not callable

# %%
list1 = [5, 2, 9, 1, 5, 6]
sorted_list = sorted(list1)
print(sorted_list)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[68], line 2
#       1 list1 = [5, 2, 9, 1, 5, 6]
# ----> 2 sorted_list = sorted(list1)
#       3 print(sorted_list)
#
# TypeError: 'list' object is not callable

# %%
string ="kishikihsore"
print(string)
# Out:
# kishikihsore

# %%
s="kishore"
list1=list(s)
print(list1)
list1[3]="s"
ns="".join(list1)
print(ns)
# Out:
# ['k', 'i', 's', 'h', 'o', 'r', 'e']
# kissore

# %%
for i in range(1,6):
    print("*"*i)
# Out:
# *
# **
# ***
# ****
# *****

# %%
list1 = ["*"*i for i in range(1,6)] 
print(list1)

# %%
list1 = [i for i in range(10)]
print(list1)
